# %% [markdown]
# # Customer Default Rates

# %% [markdown]
# ## Prepare and Explore the Data

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# Set default matplot figure size
#pylab.rcParams['figure.figsize'] = (10.0, 8.0)

# %% [markdown]
# ### Import and Prepare the data

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
# Check the first 5 rows of the data frame
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
# Column names
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#Understand the makeup of the data
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
#check the data types of each variable
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
#Rename last column 'default payment next month' to Default
#credit.columns.values[24] = 'Default'

# %%
credit['SEX'] = pd.Categorical(credit.SEX)

# %%
#Rename the categories to more meaningful names
credit["SEX"].cat.categories = ["Male", "Female"]

# %%
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# Male      11888
# Female    18112
# Name: SEX, dtype: int64

# %%
# Instead of a group by, use seaborn to plot the number of males and females
sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
# Out:
# C:\Users\jaiholkar\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# Gender split is Male 40% and Female 50%

# %%
#Data Cleansing
#check for null
#pd.isnull(credit)
#Drop rows with any column having NA/null data.
#credit.dropna()

# %%
#Converting following columns into Categorical
credit['MARRIAGE'] = pd.Categorical(credit.MARRIAGE)
credit['MARRIAGE'].cat.categories = ["Others", "Married", "Single","Divorced"]
credit['PAY_0'] = pd.Categorical(credit.PAY_0)
credit['PAY_2'] = pd.Categorical(credit.PAY_2)
credit['PAY_3'] = pd.Categorical(credit.PAY_3)
credit['PAY_4'] = pd.Categorical(credit.PAY_4)
credit['PAY_5'] = pd.Categorical(credit.PAY_5)
credit['PAY_6'] = pd.Categorical(credit.PAY_6)
credit["Default"] = credit["Default"].astype("category")

# %%
print (credit.dtypes)
# Out:
# ID                               int64
# LIMIT_BAL                        int64
# SEX                           category
# EDUCATION                        int64
# MARRIAGE                         int64
# AGE                              int64
# PAY_0                            int64
# PAY_2                            int64
# PAY_3                            int64
# PAY_4                            int64
# PAY_5                            int64
# PAY_6                            int64
# BILL_AMT1                        int64
# BILL_AMT2                        int64
# BILL_AMT3                        int64
# BILL_AMT4                        int64
# BILL_AMT5                        int64
# BILL_AMT6                        int64
# PAY_AMT1                         int64
# PAY_AMT2                         int64
# PAY_AMT3                         int64
# PAY_AMT4                         int64
# PAY_AMT5                         int64
# PAY_AMT6                         int64
# ...

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# #### Histogram

# %%
#import the matplotlib library
import pandas as pd
import matplotlib.pyplot as plt
#column names in our dataframe
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#Specify the number of bins in your histograms by adding bins='X'
plt.hist(credit['LIMIT_BAL'], bins=10)
plt.show()

# %% [markdown]
# Majority of the credit limit is below 50000

# %%
#Distribution of Age
plt.hist(credit['AGE'])
plt.show()

# %%
# Classification of Education into meaningful categories
credit['EDUCATION'] = pd.Categorical(credit.EDUCATION)
credit["EDUCATION"].cat.categories = ["Others0","Graduate", "University", "High School","Others4","Others5","Others6"]
def recode_education(series): 
    if(series == 'Others0') or (series == 'Others4') or (series == 'Others5') or (series == 'Others6'): 
        return 'Other'
    else:
        return series
credit["EDUCATION"] = credit["EDUCATION"].apply(recode_education)

# %%
# Instead of a group by, use seaborn to plot the number of males and females
sns.factorplot('EDUCATION', data=credit, kind='count', aspect=1.5)
# Out:
# C:\Users\jaiholkar\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# majority of the consumer are highly educated with who have atleast attended University or Graduate school

# %% [markdown]
# ###  Line Plots

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
#Compare Credit Limit by Age
x = credit['AGE']
y = credit['LIMIT_BAL']
#Use matplotlib to create the scatter plot using the two variables for the X and Y axes as follows:
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ###  Box Plots

# %%
#we can create box plots in matlotlib. We'll start again a having a look at our column names:
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
#build a box plot for Age:
A = credit['AGE']
plt.boxplot(A,0,'gD')
plt.show()

# %% [markdown]
# Age above 60 seems outlier

# %%
#build a box plot for Credit Limit:
A = credit['LIMIT_BAL']
plt.boxplot(A,0,'gD')
plt.show()

# %% [markdown]
# Credit limit above 500000 is rare

# %% [markdown]
# ### Correlation

# %%
#building a basic correlation coefficient matrix using pandas
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL  MARRIAGE       AGE     PAY_0  \
# ID                          1.000000   0.026179 -0.029079  0.018678 -0.030575
# LIMIT_BAL                   0.026179   1.000000 -0.108139  0.144713 -0.271214
# MARRIAGE                   -0.029079  -0.108139  1.000000 -0.414170  0.019917
# AGE                         0.018678   0.144713 -0.414170  1.000000 -0.039447
# PAY_0                      -0.030575  -0.271214  0.019917 -0.039447  1.000000
# PAY_2                      -0.011215  -0.296382  0.024199 -0.050148  0.672164
# PAY_3                      -0.018494  -0.286123  0.032688 -0.053048  0.574245
# PAY_4                      -0.002735  -0.267460  0.033122 -0.049722  0.538841
# PAY_5                      -0.022199  -0.249411  0.035629 -0.053826  0.509426
# PAY_6                      -0.020270  -0.235195  0.034345 -0.048773  0.474553
# BILL_AMT1                   0.019389   0.285430 -0.023472  0.056239  0.187068
# ...

# %% [markdown]
# Credit Default is not likely to occur with history of past payment amount with stronger realtionship with the most recent payments. Rate of default would higher with Bill Amount and Amount of previous payment

# %% [markdown]
# ### Covariance

# %%
#Calculate covariance in Pandas enter the following:
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL     MARRIAGE  \
# ID                          7.500250e+07  2.941664e+07  -131.452515
# LIMIT_BAL                   2.941664e+07  1.683446e+10 -7323.669658
# MARRIAGE                   -1.314525e+02 -7.323670e+03     0.272452
# AGE                         1.491057e+03  1.730767e+05    -1.992764
# PAY_0                      -2.975726e+02 -3.954593e+04     0.011683
# PAY_2                      -1.162770e+02 -4.603765e+04     0.015122
# PAY_3                      -1.916922e+02 -4.443225e+04     0.020421
# PAY_4                      -2.769132e+01 -4.057181e+04     0.020213
# PAY_5                      -2.178600e+02 -3.667056e+04     0.021074
# PAY_6                      -2.018774e+02 -3.509308e+04     0.020616
# BILL_AMT1                   1.236447e+07  2.727020e+09  -902.154685
# BILL_AMT2                   1.108392e+07  2.570130e+09  -802.517866
# BILL_AMT3                   1.462688e+07  2.548533e+09  -901.679085
# ...

# %% [markdown]
# Higher the Credit limit, Bill Amount and Amount of previous payment is likely to have reduce the Default. Higher Payment history is likely to reduce credit default rate.

# %%
# Distribution of age, with an overlay of a density plot
age = credit['AGE']
age_dist = sns.distplot(age)
age_dist.set_title("Distribution of Passengers' Ages")
# Out:
# Text(0.5, 1.0, "Distribution of Passengers' Ages")

# %%
# Another way to plot a histogram of ages is shown below
credit['AGE'].hist(bins=100)

# %%
# Linear plot of age vs. Default
sns.lmplot('AGE', 'default payment next month', data=credit)

#credit.columns

# %% [markdown]
# Rate of default is slightly higher for older consumers

# %%
# Default vs. Age grouped by Gender
sns.lmplot('AGE', 'default payment next month', data=credit, hue='SEX')

# %% [markdown]
# Rate of default is higher for male as compared to female with the increase in age

# %%
# Default vs. Age grouped by EDUCATTION
sns.lmplot('AGE', 'default payment next month', data=credit, hue='EDUCATION')

# %% [markdown]
# Rate of default increases sharply with age for people not with University degree or attend gradute school.

# %%
#Converting following columns into Categorical
credit['MARRIAGE'] = pd.Categorical(credit.MARRIAGE)
credit['MARRIAGE'].cat.categories = ["Others", "Married", "Single","Divorced"]

# %%
# Default vs. Age gruped by EDUCATTION
sns.lmplot('AGE', 'default payment next month', data=credit, hue='MARRIAGE')

# %% [markdown]
# Divorced people are more likley to default as the age increases.

# %%
# Create a generation bin
generations = [10,20,30,40,50,60,70,80]
# Default vs. Age grouped by Gender
sns.lmplot('AGE', 'default payment next month', data=credit, hue='SEX',x_bins=generations)

# %% [markdown]
# Both male and female in 70s seems to have higher default rates

# %%
# Default vs. Age grouped by EDUCATTION
sns.lmplot('AGE', 'default payment next month', data=credit, hue='EDUCATION',x_bins=generations)

# %% [markdown]
# People with no education tends to default in 20s where as people who have attended graduate school or high school tends to default in 70s.

# %%
# Default vs. Age grouped by Marriage status
sns.lmplot('AGE', 'default payment next month', data=credit, x_bins=generations,hue='MARRIAGE')

# %% [markdown]
# Rate of default is higher for divorced individual and where as default rate drops with age for single and unknown marriage status

# %%
# Create a Credit Limit  bin
limit_range = [0, 25000,50000,100000,150000,250000, 500000, 1000000]
# Default vs. Credit Limit grouped by Gender
sns.lmplot('LIMIT_BAL', 'default payment next month', data=credit, hue='SEX',x_bins=limit_range)

# %% [markdown]
# Rate of default reduces with higher credit limit for both gender

# %%
# Default vs. Credit Limit grouped by EDUCATTION
sns.lmplot('LIMIT_BAL', 'default payment next month', data=credit, hue='EDUCATION', x_bins=limit_range)

# %% [markdown]
# People with unknown education tends to have lower credit limit

# %%
# Default vs. Credit Limit grouped by Marriage status
sns.lmplot('LIMIT_BAL', 'default payment next month', data=credit, x_bins=limit_range,hue='MARRIAGE')

# %% [markdown]
# Rate of default does not reduce with higher credit limit whereas the default rate falls sharply with higher credit limit
